# %% [markdown]
# # End To End Big Data Project

# %% [markdown]
# We will ofcourse not be running our Code on Jupyter Notebook

# %% [markdown]
# that doesn't means Jupyter Notebook is not helpful, rather it is still best way to do POC and also get insight into the data and code.

# %% [markdown]
# We should be able to write a code which can be worked by multiple people in a company and ofcourse follows
# good coding standard (Modular, Configs ,Yaml, Environment, Testing, Environment)

# %% [markdown]
# Can we Directly add data To Bucket Rather than Writing Code

# %%
Can't we use spark dataframe? Why do we need to use pandas dataframe?
